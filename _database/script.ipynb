-- %% [markdown]
-- # [warehouses_manager]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [warehouses_manager]    Script Date: 26/11/2025 10:47:13 ******/
CREATE DATABASE [warehouses_manager]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'warehouses_manager', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\warehouses_manager.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'warehouses_manager_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\warehouses_manager_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [warehouses_manager] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [warehouses_manager].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [warehouses_manager] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [warehouses_manager] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [warehouses_manager] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [warehouses_manager] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [warehouses_manager] SET ARITHABORT OFF 
GO
ALTER DATABASE [warehouses_manager] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [warehouses_manager] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [warehouses_manager] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [warehouses_manager] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [warehouses_manager] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [warehouses_manager] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [warehouses_manager] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [warehouses_manager] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [warehouses_manager] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [warehouses_manager] SET  DISABLE_BROKER 
GO
ALTER DATABASE [warehouses_manager] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [warehouses_manager] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [warehouses_manager] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [warehouses_manager] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [warehouses_manager] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [warehouses_manager] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [warehouses_manager] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [warehouses_manager] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [warehouses_manager] SET  MULTI_USER 
GO
ALTER DATABASE [warehouses_manager] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [warehouses_manager] SET DB_CHAINING OFF 
GO
ALTER DATABASE [warehouses_manager] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [warehouses_manager] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [warehouses_manager] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [warehouses_manager] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [warehouses_manager] SET QUERY_STORE = ON
GO
ALTER DATABASE [warehouses_manager] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [warehouses_manager]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InventoryIssueDetails]

-- %%
/****** Object:  Table [dbo].[InventoryIssueDetails]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InventoryIssueDetails](
	[DetailId] [int] IDENTITY(1,1) NOT NULL,
	[IssueId] [int] NULL,
	[MaterialId] [int] NULL,
	[Quantity] [decimal](18, 2) NULL,
	[UnitPrice] [decimal](18, 2) NULL,
	[TotalPrice]  AS ([Quantity]*[UnitPrice]),
PRIMARY KEY CLUSTERED 
(
	[DetailId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InventoryIssues]

-- %%
/****** Object:  Table [dbo].[InventoryIssues]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InventoryIssues](
	[IssueId] [int] IDENTITY(1,1) NOT NULL,
	[IssueCode] [nvarchar](50) NULL,
	[WarehouseId] [int] NULL,
	[CreatedBy] [int] NULL,
	[CreatedAt] [datetime] NULL,
	[Description] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[IssueId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InventoryReceiptDetails]

-- %%
/****** Object:  Table [dbo].[InventoryReceiptDetails]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InventoryReceiptDetails](
	[DetailId] [int] IDENTITY(1,1) NOT NULL,
	[ReceiptId] [int] NULL,
	[MaterialId] [int] NULL,
	[Quantity] [int] NOT NULL,
	[UnitPrice] [decimal](18, 2) NULL,
	[TotalPrice]  AS ([Quantity]*[UnitPrice]),
PRIMARY KEY CLUSTERED 
(
	[DetailId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InventoryReceipts]

-- %%
/****** Object:  Table [dbo].[InventoryReceipts]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InventoryReceipts](
	[ReceiptId] [int] IDENTITY(1,1) NOT NULL,
	[ReceiptCode] [nvarchar](50) NULL,
	[WarehouseId] [int] NULL,
	[CreatedBy] [int] NULL,
	[CreatedAt] [datetime] NULL,
	[Description] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[ReceiptId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MaterialCategories]

-- %%
/****** Object:  Table [dbo].[MaterialCategories]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MaterialCategories](
	[CategoryId] [int] IDENTITY(1,1) NOT NULL,
	[CategoryName] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[CategoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Materials]

-- %%
/****** Object:  Table [dbo].[Materials]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Materials](
	[MaterialId] [int] IDENTITY(1,1) NOT NULL,
	[MaterialCode] [nvarchar](50) NULL,
	[MaterialName] [nvarchar](150) NULL,
	[Unit] [decimal](18, 0) NOT NULL,
	[CategoryId] [int] NULL,
	[Quantity] [int] NOT NULL,
	[Description] [nvarchar](255) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaterialId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[MaterialCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StockLogs]

-- %%
/****** Object:  Table [dbo].[StockLogs]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StockLogs](
	[LogId] [int] IDENTITY(1,1) NOT NULL,
	[MaterialId] [int] NULL,
	[WarehouseId] [int] NULL,
	[RefType] [int] NULL,
	[RefId] [int] NULL,
	[QuantityChange] [decimal](18, 2) NULL,
	[FinalQuantity] [decimal](18, 2) NULL,
	[CreatedAt] [datetime] NULL,
	[CreatedBy] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[LogId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Stocks]

-- %%
/****** Object:  Table [dbo].[Stocks]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Stocks](
	[StockId] [int] IDENTITY(1,1) NOT NULL,
	[WarehouseId] [int] NULL,
	[MaterialId] [int] NULL,
	[Quantity] [decimal](18, 2) NULL,
	[LastUpdated] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[StockId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[Username] [nvarchar](50) NULL,
	[PasswodHash] [nvarchar](255) NULL,
	[FullName] [nvarchar](100) NULL,
	[Role] [nvarchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Warehouses]

-- %%
/****** Object:  Table [dbo].[Warehouses]    Script Date: 26/11/2025 10:47:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Warehouses](
	[WarehouseId] [int] IDENTITY(1,1) NOT NULL,
	[WarehouseName] [nvarchar](100) NULL,
	[Location] [nvarchar](200) NULL,
	[Description] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[WarehouseId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Inventory__Creat__5535A963]

-- %%
ALTER TABLE [dbo].[InventoryIssues] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Inventory__Creat__4CA06362]

-- %%
ALTER TABLE [dbo].[InventoryReceipts] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Materials__IsAct__4222D4EF]

-- %%
ALTER TABLE [dbo].[Materials] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__StockLogs__Creat__5DCAEF64]

-- %%
ALTER TABLE [dbo].[StockLogs] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Stocks__Quantity__46E78A0C]

-- %%
ALTER TABLE [dbo].[Stocks] ADD  DEFAULT ((0)) FOR [Quantity]
GO

-- %% [markdown]
-- # [DF__Stocks__LastUpda__47DBAE45]

-- %%
ALTER TABLE [dbo].[Stocks] ADD  DEFAULT (getdate()) FOR [LastUpdated]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__38996AB5]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Users__CreatedAt__398D8EEE]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [FK__Inventory__Issue__5812160E]

-- %%
ALTER TABLE [dbo].[InventoryIssueDetails]  WITH CHECK ADD FOREIGN KEY([IssueId])
REFERENCES [dbo].[InventoryIssues] ([IssueId])
GO

-- %% [markdown]
-- # [FK__Inventory__Mater__59063A47]

-- %%
ALTER TABLE [dbo].[InventoryIssueDetails]  WITH CHECK ADD FOREIGN KEY([MaterialId])
REFERENCES [dbo].[Materials] ([MaterialId])
GO

-- %% [markdown]
-- # [FK__Inventory__Creat__5441852A]

-- %%
ALTER TABLE [dbo].[InventoryIssues]  WITH CHECK ADD FOREIGN KEY([CreatedBy])
REFERENCES [dbo].[Users] ([UserId])
GO

-- %% [markdown]
-- # [FK__Inventory__Wareh__534D60F1]

-- %%
ALTER TABLE [dbo].[InventoryIssues]  WITH CHECK ADD FOREIGN KEY([WarehouseId])
REFERENCES [dbo].[Warehouses] ([WarehouseId])
GO

-- %% [markdown]
-- # [FK__Inventory__Mater__5070F446]

-- %%
ALTER TABLE [dbo].[InventoryReceiptDetails]  WITH CHECK ADD FOREIGN KEY([MaterialId])
REFERENCES [dbo].[Materials] ([MaterialId])
GO

-- %% [markdown]
-- # [FK__Inventory__Recei__4F7CD00D]

-- %%
ALTER TABLE [dbo].[InventoryReceiptDetails]  WITH CHECK ADD FOREIGN KEY([ReceiptId])
REFERENCES [dbo].[InventoryReceipts] ([ReceiptId])
GO

-- %% [markdown]
-- # [FK__Inventory__Creat__4BAC3F29]

-- %%
ALTER TABLE [dbo].[InventoryReceipts]  WITH CHECK ADD FOREIGN KEY([CreatedBy])
REFERENCES [dbo].[Users] ([UserId])
GO

-- %% [markdown]
-- # [FK__Inventory__Wareh__4AB81AF0]

-- %%
ALTER TABLE [dbo].[InventoryReceipts]  WITH CHECK ADD FOREIGN KEY([WarehouseId])
REFERENCES [dbo].[Warehouses] ([WarehouseId])
GO

-- %% [markdown]
-- # [FK__Materials__Categ__412EB0B6]

-- %%
ALTER TABLE [dbo].[Materials]  WITH CHECK ADD FOREIGN KEY([CategoryId])
REFERENCES [dbo].[MaterialCategories] ([CategoryId])
GO

-- %% [markdown]
-- # [FK__StockLogs__Creat__5EBF139D]

-- %%
ALTER TABLE [dbo].[StockLogs]  WITH CHECK ADD FOREIGN KEY([CreatedBy])
REFERENCES [dbo].[Users] ([UserId])
GO

-- %% [markdown]
-- # [FK__StockLogs__Mater__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[StockLogs]  WITH CHECK ADD FOREIGN KEY([MaterialId])
REFERENCES [dbo].[Materials] ([MaterialId])
GO

-- %% [markdown]
-- # [FK__StockLogs__Wareh__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[StockLogs]  WITH CHECK ADD FOREIGN KEY([WarehouseId])
REFERENCES [dbo].[Warehouses] ([WarehouseId])
GO

-- %% [markdown]
-- # [FK__Stocks__Material__45F365D3]

-- %%
ALTER TABLE [dbo].[Stocks]  WITH CHECK ADD FOREIGN KEY([MaterialId])
REFERENCES [dbo].[Materials] ([MaterialId])
GO

-- %% [markdown]
-- # [FK__Stocks__Warehous__44FF419A]

-- %%
ALTER TABLE [dbo].[Stocks]  WITH CHECK ADD FOREIGN KEY([WarehouseId])
REFERENCES [dbo].[Warehouses] ([WarehouseId])
GO

-- %% [markdown]
-- # [warehouses_manager]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [warehouses_manager] SET  READ_WRITE 
GO
